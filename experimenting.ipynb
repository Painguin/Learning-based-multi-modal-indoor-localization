# %% [markdown]
# ## Imports

# %%
# Pytorch
import torch
from torch.nn import CrossEntropyLoss, Conv2d, Linear, ReLU, Sequential, Sigmoid, Tanh, Softmax, MSELoss
from torch.optim import SGD, Adam

# helper
from os.path import join
import numpy as np
from math import sqrt

# Visualization
import pandas as pd

# %% [markdown]
# ## Data acquisition

# %%
DATA_FOLDER = 'datasets/'
BC_NEW_DENSE_FOLDER = join(DATA_FOLDER, 'bc_new_dense')
ZIG_ZAG2_PATH = join(BC_NEW_DENSE_FOLDER, 'zig_zag2.csv')
ANCHORS_PATH = join(BC_NEW_DENSE_FOLDER, 'anchors_bc_atrium_dense.csv')

# %%
data_raw = pd.read_csv(ZIG_ZAG2_PATH)
data_raw
# Out:
#            timestamp             device_id  system_id  \
# 0      1557062000727  14954135790684542069       7586
# 1      1557062000731  16616973326163504182       7592
# 2      1557062000741  14954135790684542069       7586
# 3      1557062000748  16616973326163504182       7592
# 4      1557062000748  16616973326163504182       7582
# ...              ...                   ...        ...
# 22874  1557062212254                 28486     115200
# 22875  1557062210445  16616973326163504182       7592
# 22876  1557062210447  14954135790684542069       7586
# 22877  1557062212306                 28486     115200
# 22878  1557062210476  14614612876646121370       7585
#
#                                   anchor_id       px        py        pz  \
# 0                                       NaN      NaN       NaN       NaN
# 1                         dc:8b:28:54:d7:8d      NaN       NaN       NaN
# 2                                       NaN      NaN       NaN       NaN
# 3                         b8:08:cf:a0:bf:1d      NaN       NaN       NaN
# 4                                     1-250      NaN       NaN       NaN
# ...                                     ...      ...       ...       ...
# 22874                                0x6F3F  3.75000  7.111000  1.300000
# 22875                     dc:8b:28:54:d7:f1      NaN       NaN       NaN
# 22876                                   NaN      NaN       NaN       NaN
# 22877                                0x6F2B  3.87000  6.940000  1.300000
# 22878  17eba1fb-bd0c-2b8b-8530-fcfec019262c  4.62488  5.484211  1.139468
#
#         theta_x   theta_y   theta_z  ...  dist_var  txpower  rssi  \
# 0      0.947485  0.055430  1.289884  ...       NaN      NaN   NaN
# 1           NaN       NaN       NaN  ...  0.178929      NaN -71.0
# 2      0.947991  0.051225  1.293103  ...       NaN      NaN   NaN
# 3           NaN       NaN       NaN  ...  0.822649      NaN -61.0
# 4           NaN       NaN       NaN  ...       NaN    -77.0 -83.0
# ...         ...       ...       ...  ...       ...      ...   ...
# 22874       NaN       NaN       NaN  ...       NaN      NaN -80.0
# 22875       NaN       NaN       NaN  ...  5.866084      NaN -65.0
# 22876  1.068343 -0.014032 -1.169306  ...       NaN      NaN   NaN
# 22877       NaN       NaN       NaN  ...       NaN      NaN -86.0
# 22878  0.720278  0.044309 -1.963033  ...       NaN      NaN   NaN
#
#        ble_channel  calib_param_tx  calib_param_n     acc_x     acc_y  \
# 0              NaN             NaN            NaN -0.275427  8.064031
# 1              NaN             NaN            NaN       NaN       NaN
# 2              NaN             NaN            NaN -0.519719  8.078402
# 3              NaN             NaN            NaN       NaN       NaN
# 4              NaN           -77.0            2.0       NaN       NaN
# ...            ...             ...            ...       ...       ...
# 22874          NaN             NaN            NaN       NaN       NaN
# 22875          NaN             NaN            NaN       NaN       NaN
# 22876          NaN             NaN            NaN -1.175955  9.929751
# 22877          NaN             NaN            NaN       NaN       NaN
# 22878          NaN             NaN            NaN       NaN       NaN
#
#           acc_z  is_step_detected
# 0      5.166058               0.0
# 1           NaN               NaN
# 2      5.486990               0.0
# 3           NaN               NaN
# 4           NaN               NaN
# ...         ...               ...
# 22874       NaN               NaN
# 22875       NaN               NaN
# 22876  4.260740               0.0
# 22877       NaN               NaN
# 22878       NaN               NaN
#
# [22879 rows x 25 columns]

# %%
data_anchors = pd.read_csv(ANCHORS_PATH)
data_anchors
# Out:
#     system_id                              anchor_id       px       py  \
# 0      115200                                 0x6F2B  15.1070  25.2470
# 1      115200                                 0x6F29   2.0550  45.6500
# 2      115200                                 0x6F13  13.8270   7.9280
# 3      115200                                 0x6F3F   1.9350   3.7260
# 4        7581                        u1uwhdqdy4vx2q0   0.0000  10.4900
# 5        7581                        9iaj4ym9u2shxdh   6.5390   0.9600
# 6        7581                        xehph6l77u7smwo   0.0000  18.7080
# 7        7581                        53saut0wvhrpeyk  13.8480   7.3670
# 8        7592                      dc:8b:28:54:da:bc   0.2250  30.8470
# 9        7592                      dc:8b:28:54:d8:05   2.7250   7.3140
# 10       7592                      dc:8b:28:54:d7:f1  14.9370  19.0540
# 11       7592                      dc:8b:28:54:d7:d8   0.2110  16.0640
# 12       7592                      dc:8b:28:54:e2:ff  13.8010   3.7620
# 13       7592                      dc:8b:28:54:d7:8d  12.0190  42.9540
# 14       7592                      b8:08:cf:a0:bf:1d   6.5600  13.9060
# 15       7582                                  1-250  11.8810   7.6830
# 16       7582                                  2-235  11.8810  14.8500
# 17       7582                                  2-231   2.0690  14.8500
# 18       7582                                  1-249   2.0690   7.6830
# 19       7582                                  1-248  11.8810   3.7220
# 20       7585   17eba1f6-bd0c-2b8b-8559-75e8b171730e   9.6213   6.3959
# 21       7585   17eba1fb-bd0c-2b8b-8530-fcfec019262c   9.4597   5.6944
#
#         pz  theta_x  theta_y  theta_z  scale_x  scale_y
# 0   1.8120      NaN      NaN      NaN      NaN      NaN
# 1   1.8780      NaN      NaN      NaN      NaN      NaN
# 2   1.9050      NaN      NaN      NaN      NaN      NaN
# 3   1.9970      NaN      NaN      NaN      NaN      NaN
# 4   1.6100   1.5708      0.0  1.57080    1.050     0.63
# 5   1.5550   1.5708      0.0  3.14159    0.575     0.42
# 6   1.4350   1.5708      0.0  1.57080    0.420     0.59
# 7   1.4560   1.5708      0.0 -1.57080    0.350     0.54
# 8   0.9360      NaN      NaN      NaN      NaN      NaN
# 9   5.1600      NaN      NaN      NaN      NaN      NaN
# 10  0.9450      NaN      NaN      NaN      NaN      NaN
# 11  0.9150      NaN      NaN      NaN      NaN      NaN
# 12  0.9170      NaN      NaN      NaN      NaN      NaN
# 13  0.9220      NaN      NaN      NaN      NaN      NaN
# 14  2.5000      NaN      NaN      NaN      NaN      NaN
# 15  1.5000      NaN      NaN      NaN      NaN      NaN
# 16  1.5000      NaN      NaN      NaN      NaN      NaN
# 17  1.5000      NaN      NaN      NaN      NaN      NaN
# 18  1.5000      NaN      NaN      NaN      NaN      NaN
# 19  1.5000      NaN      NaN      NaN      NaN      NaN
# 20  1.1182   0.0000      0.0  0.03950      NaN      NaN
# 21  1.2542   0.0000      0.0  6.20590      NaN      NaN

# %%
a = data_anchors.fillna(0)

# %%
b = a.iloc[:,3:]

# %%
torch.FloatTensor(b.values).shape
# Out:
# torch.Size([22, 7])

# %% [markdown]
# ## Data exploration and cleaning

# %%
data_raw.columns
# Out:
# Index(['timestamp', 'device_id', 'system_id', 'anchor_id', 'px', 'py', 'pz',
#        'theta_x', 'theta_y', 'theta_z', 'dx', 'dy', 'dz', 'distance',
#        'dist_error', 'dist_var', 'txpower', 'rssi', 'ble_channel',
#        'calib_param_tx', 'calib_param_n', 'acc_x', 'acc_y', 'acc_z',
#        'is_step_detected'],
#       dtype='object')

# %%
columns_of_interest = ['timestamp', 'system_id', 'px', 'py', 'pz', 'distance', 'rssi', 'anchor_id']

# %%
data_of_interest = data_raw[columns_of_interest]
data_of_interest.head()
# Out:
#        timestamp  system_id  px  py  pz   distance  rssi          anchor_id
# 0  1557062000727       7586 NaN NaN NaN        NaN   NaN                NaN
# 1  1557062000731       7592 NaN NaN NaN  43.299000 -71.0  dc:8b:28:54:d7:8d
# 2  1557062000741       7586 NaN NaN NaN        NaN   NaN                NaN
# 3  1557062000748       7592 NaN NaN NaN  10.181000 -61.0  b8:08:cf:a0:bf:1d
# 4  1557062000748       7582 NaN NaN NaN   1.995262 -83.0              1-250

# %%
data_of_interest.describe()
# Out:
#           timestamp      system_id           px           py           pz  \
# count  2.287900e+04   22879.000000  9543.000000  9543.000000  9543.000000
# mean   1.557062e+12   41433.665326     6.686781    13.263270     1.260599
# std    6.058879e+04   49968.774968     3.190699     8.130622     0.096490
# min    1.557062e+12    7581.000000     0.000000     0.000000     0.301120
# 25%    1.557062e+12    7586.000000     4.090456     7.307947     1.300000
# 50%    1.557062e+12    7586.000000     6.574000    11.994000     1.300000
# 75%    1.557062e+12  115200.000000     9.119000    19.859157     1.300000
# max    1.557062e+12  115200.000000    24.328000    30.862000     1.571681
#
#            distance          rssi
# count  10075.000000  10075.000000
# mean      17.860901    -82.573995
# std       10.951266     14.081788
# min        0.281838   -109.000000
# 25%        9.785000    -93.000000
# 50%       16.000000    -87.000000
# 75%       23.623500    -72.000000
# max       64.387000      0.000000

# %%
data_anchors.anchor_id.unique()
# Out:
# array(['0x6F2B', '0x6F29', '0x6F13', '0x6F3F', 'u1uwhdqdy4vx2q0',
#        '9iaj4ym9u2shxdh', 'xehph6l77u7smwo', '53saut0wvhrpeyk',
#        'dc:8b:28:54:da:bc', 'dc:8b:28:54:d8:05', 'dc:8b:28:54:d7:f1',
#        'dc:8b:28:54:d7:d8', 'dc:8b:28:54:e2:ff', 'dc:8b:28:54:d7:8d',
#        'b8:08:cf:a0:bf:1d', '1-250', '2-235', '2-231', '1-249', '1-248',
#        '17eba1f6-bd0c-2b8b-8559-75e8b171730e',
#        '17eba1fb-bd0c-2b8b-8530-fcfec019262c'], dtype=object)

# %% [markdown]
# ## Data processing

# %%
N = len(data)
split_ratio = 0.8
split_index = int(split_ratio * N)

# %%
data_torch = torch.tensor(data)
data_torch
# Out:
# tensor([[-64, -56, -61,  ..., -82, -81,   1],
#         [-68, -57, -61,  ..., -85, -85,   1],
#         [-63, -60, -60,  ..., -85, -84,   1],
#         ...,
#         [-62, -59, -46,  ..., -87, -88,   4],
#         [-62, -58, -52,  ..., -90, -85,   4],
#         [-59, -50, -45,  ..., -88, -87,   4]])

# %%
# generate random indices to split the data
random_indices = np.random.permutation(2000)
train_indices = random_indices[:split_index]
test_indices = random_indices[split_index:]

# split the data into train and test samples
train_data = data_torch[train_indices]
test_data = data_torch[test_indices]

# separate the input columns from the target column
train_input = train_data[:, :7].float()
train_target = train_data[:, 7] - 1
test_input = test_data[:, :7].float()
test_target = test_data[:, 7] - 1

# %% [markdown]
# ## Train and evaluation functions

# %%
criterion = CrossEntropyLoss()
batch_size = 10
nb_epochs = 25

# %%
def train_model(model, train_input, train_target, nb_epochs=nb_epochs, batch_size=batch_size):
    """Train a model"""
    
    optimizer = Adam(model.parameters())

    for _ in range(nb_epochs):
        for b in range(0, train_input.size(0), batch_size):
            output = model(train_input.narrow(0, b, batch_size))
            loss = criterion(output, train_target.narrow(0, b, batch_size))
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

# %%
def compute_nb_errors(model, data_input, data_target):
    """Compute the number of mismatched predictions"""
    
    nb_errors = 0
    for b in range(0, data_input.size(0), batch_size):
        output = model(data_input.narrow(0, b, batch_size))
        _, predictions = output.max(1)
        nb_errors += (predictions != data_target.narrow(0, b, batch_size)).sum()
        
    return int(nb_errors)

# %%
def weight_reset(m):
    """Reinitilize every linear and convolutional layer parameters in the model"""
    if isinstance(m, Conv2d) or isinstance(m, Linear):
        m.reset_parameters()

# %%
def train_and_evaluate(model, nb_trials=10):
    p_errs = torch.zeros(nb_trials)
    
    for i in range(nb_trials):
        model.apply(weight_reset)
        
        # train
        train_model(model, train_input, train_target)

        # evaluate
        n_err = compute_nb_errors(model, test_input, test_target)
        p_err = n_err / N
        p_errs[i] = p_err
    
    p_err_mean = p_errs.mean().item()
    std = p_errs.std().item()
    ci_95 = 1.96 * std / sqrt(nb_trials)
    
    return {'error_rate': p_err_mean,
            'std': std,
            'confidence_interval_95': ci_95
           }

# %%
model = Sequential(
    Linear(7, 4)
)

# %%
train_and_evaluate(model)
# Out:
# {'error_rate': 0.011749999597668648,
#  'std': 0.0016372401732951403,
#  'confidence_interval_95': 0.0010147719727709198}
